# %% [markdown]
# <a href="https://colab.research.google.com/github/amanteur/TDA_Cover_detection/blob/main/Practics/TDA_CoverDetection_Practics_4_SiameseNetwork_ContrastiveLoss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libs and extracting

# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torch import FloatTensor
import tqdm
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_dir = '/content/drive/MyDrive/Colab Notebooks/CourseWork/pers_feat_datasets/'
df_dict = {}
for _, _, files in os.walk(root_dir):
  for file in files:
    name = file.split('.')[0]
    df = pd.read_json(root_dir + file)
    df_dict [name] = df

# %% [markdown]
# ### Creating own dataset

# %%
#our dataset
class MyDataset(Dataset):
  def __init__(self, df, setSize, feature='Silhouette'):
    self.df = df
    self.feature = feature
    self.setSize = setSize
  def __len__(self):
    return self.setSize
  #creating separate dataframes for originals and covers
  def _separate_dfs(self, df):
    df_query = df.drop_duplicates(['name'])
    df_search = df[~df.index.isin(df_query.index)]
    return df_query, df_search
  def __getitem__(self, idx):
    origs, covers = self._separate_dfs(self.df)
    song1 = None
    song2 = None
    label = None
    # same songs
    if idx % 2 == 0:
      # get random row from origs
      song1 = origs.sample()[['name', self.feature]]
      song1_name = song1['name'].iloc[0]
      # find same song in covers
      song2 = covers.loc[covers['name'] == song1_name].sample()[self.feature]
      label = 1
    else:
      # get random row from origs
      song1 = origs.sample()[['name', self.feature]]
      song1_name = song1['name'].iloc[0]
      # find another song in covers
      song2 = covers.loc[covers['name'] != song1_name].sample()[self.feature]
      label = 0
    return FloatTensor(song1[self.feature].iloc[0]), \
           FloatTensor(song2.iloc[0]), \
           torch.from_numpy(np.array([label], dtype=np.float32))

# %%
class OneShotEvalSet(Dataset):
  def __init__(self, df, setSize, nWay, feature='Silhouette'):
    self.df = df
    self.feature = feature
    self.setSize = setSize
    self.nWay = nWay
  def __len__(self):
    return self.setSize
  def __getitem__(self, idx):
    # get main song
    song_init = self.df.sample()[['name', self.feature]]
    song_name = song_init['name'].iloc[0]
    # first song is the same
    testSet = [FloatTensor(self.df.loc[(self.df['name'] == song_name) & (self.df.index != song_init.index[0])].sample()[self.feature].iloc[0])]
    label = [1]
    song_search_idx = []
    for i in range(self.nWay - 1):
      song_search = self.df.loc[self.df['name'] != song_name].sample()[self.feature]
      while song_search.index[0] in song_search_idx:
        song_search = self.df.loc[self.df['name'] != song_name].sample()[self.feature]
      song_search = FloatTensor(song_search.iloc[0])
      testSet.append(song_search)
      label.append(0)
    return FloatTensor(song_init[self.feature].iloc[0]), \
           testSet, \
           torch.from_numpy(np.array([label], dtype = int))

# %%
#splitting in train and test
from sklearn.model_selection import train_test_split

def split_data(df_dict, label_col='name', test_size=0.2, random_state=42):
  #extracting labels aka songs' names
  labels = set(df_dict[np.random.choice(list(df_dict))][label_col].tolist())
  #making train/test labels
  lbl_train, lbl_test = train_test_split(list(labels), test_size=test_size, random_state=random_state)

  train_test_dict = {}
  for name, df in df_dict.items():
    train_df = df[df[label_col].isin(lbl_train)]
    test_df = df[df[label_col].isin(lbl_test)]

    train_test_dict.setdefault(name,{})
    train_test_dict[name]['train'] = train_df
    train_test_dict[name]['test'] = test_df

  return train_test_dict

# %%
train_test_dict = split_data(df_dict, test_size=0.2)

# %%
#defining train val datasets
dataSize = 1000 # self-defined dataset size
TRAIN_PCT = 0.8 # percentage of entire dataset for training
train_size = int(dataSize * TRAIN_PCT)
val_size = dataSize - train_size

train_df = train_test_dict['ms_orig']['train']
dataset = MyDataset(train_df, dataSize)
train_set, val_set = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_set, batch_size=16, num_workers=2)
val_loader = DataLoader(val_set, batch_size=1, num_workers=2, shuffle=True)

# %%
# create the test set for final testing
testSize = 200
numWay = 10
test_df = train_test_dict['ms_orig']['test']
test_set = OneShotEvalSet(test_df, testSize, numWay)
test_loader = DataLoader(test_set, batch_size = 1, num_workers = 1, shuffle=True)

# %%
# showing a sample input of a training set
count0 = 0
count1 = 0
for sil1, sil2, label in train_loader:
  if label[0] == 1:
      plt.subplot(1,2,1)
      plt.plot(sil1[0][0])
      plt.subplot(1,2,2)
      plt.plot(sil2[0][0])
      break

# %%
# showing a sample input of the testing set
count = 0
plt.figure(figsize=(50, 5))
for mainSong, songset, label in test_loader:
  for count, song in enumerate(songset):
    plt.subplot(1, len(songset)+1, count+1)
    plt.plot(song[0][0])
  plt.subplot(1, len(songset)+1, len(songset)+1)
  plt.plot(mainSong[0][0])
  count += 1
  break

# %% [markdown]
# ### Siamese Net

# %%
class Net(nn.Module):
  def __init__(self):
    super().__init__()

    self.linear1 = nn.Linear(500, 128)
    self.out = nn.Linear(128, 1)
    self.sigmoid = nn.Sigmoid()
    self.dropout = nn.Dropout(0.1)
    self.bn1 = nn.BatchNorm1d(1)

  def forward(self, x1, x2):
    x1 = F.relu(self.linear1(x1))
    x1 = self.sigmoid(x1)

    x2 = F.relu(self.linear1(x2))
    x2 = self.sigmoid(x2)

    x = torch.abs(x1 - x2)
    x = self.out(x)
    return x

# %%
#creating the original network and couting the paramenters of different networks
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
siameseBaseLine = Net()
siameseBaseLine = siameseBaseLine.to(device)

def count_parameters(model):
    temp = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'The model architecture:\n\n', model)
    print(f'\nThe model has {temp:,} trainable parameters')
    
count_parameters(siameseBaseLine)
# Out:
# The model architecture:
#
#  Net(
#   (linear1): Linear(in_features=500, out_features=128, bias=True)
#   (out): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.1, inplace=False)
#   (bn1): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
#
# The model has 64,259 trainable parameters

# %%
# saving and loading checkpoint mechanisms
def save_checkpoint(save_path, model, optimizer, val_loss):
    if save_path==None:
        return
    save_path = save_path 
    state_dict = {'model_state_dict': model.state_dict(),
                  'optimizer_state_dict': optimizer.state_dict(),
                  'val_loss': val_loss}

    torch.save(state_dict, save_path)

    print(f'Model saved to ==> {save_path}')

def load_checkpoint(model, optimizer, save_path):
    state_dict = torch.load(save_path)
    model.load_state_dict(state_dict['model_state_dict'])
    optimizer.load_state_dict(state_dict['optimizer_state_dict'])
    val_loss = state_dict['val_loss']
    print(f'Model loaded from <== {save_path}')
    
    return val_loss

# %%
# training and validation after every epoch
def train(model, train_loader, val_loader, num_epochs, criterion, save_name):
    best_val_loss = float("Inf") 
    train_losses = []
    val_losses = []
    cur_step = 0
    for epoch in range(num_epochs):
        running_loss = 0.0
        model.train()
        print("Starting epoch " + str(epoch+1))
        for song1, song2, labels in train_loader:
            
            # Forward
            song1 = song1.to(device)
            song2 = song2.to(device)
            labels = labels.to(device)
            outputs = model(song1, song2)
            loss = criterion(outputs, labels.unsqueeze(dim=1))
            
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        
        val_running_loss = 0.0
        with torch.no_grad():
            model.eval()
            for song1, song2, labels in val_loader:
                song1 = song1.to(device)
                song2 = song2.to(device)
                labels = labels.to(device)
                outputs = model(song1, song2)
                loss = criterion(outputs, labels.unsqueeze(dim=1))
                val_running_loss += loss.item()
        avg_val_loss = val_running_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        
        print('Epoch [{}/{}],Train Loss: {:.4f}, Valid Loss: {:.8f}'
            .format(epoch+1, num_epochs, avg_train_loss, avg_val_loss))
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            save_checkpoint(save_name, model, optimizer, best_val_loss)
    
    print("Finished Training")  
    return train_losses, val_losses

# %%
# actual training
import torch.optim as optim

optimizer = optim.Adam(siameseBaseLine.parameters(), lr = 0.01)
num_epochs = 100
criterion = nn.BCEWithLogitsLoss()
save_path = 'siameseNet.pt'
train_losses, val_losses = train(siameseBaseLine, train_loader, val_loader, num_epochs, criterion, save_path)
# Out:
# Starting epoch 1
# Epoch [1/100],Train Loss: 0.6953, Valid Loss: 0.68593504
# Model saved to ==> siameseNet.pt
# Starting epoch 2
# Epoch [2/100],Train Loss: 0.6908, Valid Loss: 0.68283074
# Model saved to ==> siameseNet.pt
# Starting epoch 3
# Epoch [3/100],Train Loss: 0.6794, Valid Loss: 0.67357334
# Model saved to ==> siameseNet.pt
# Starting epoch 4
# Epoch [4/100],Train Loss: 0.6598, Valid Loss: 0.67113090
# Model saved to ==> siameseNet.pt
# Starting epoch 5
# Epoch [5/100],Train Loss: 0.6681, Valid Loss: 0.67000540
# Model saved to ==> siameseNet.pt
# Starting epoch 6
# Epoch [6/100],Train Loss: 0.6382, Valid Loss: 0.62398101
# Model saved to ==> siameseNet.pt
# Starting epoch 7
# Epoch [7/100],Train Loss: 0.6470, Valid Loss: 0.62823878
# Starting epoch 8
# Epoch [8/100],Train Loss: 0.6365, Valid Loss: 0.64397841
# Starting epoch 9
# Epoch [9/100],Train Loss: 0.6105, Valid Loss: 0.60375906
# Model saved to ==> siameseNet.pt
# Starting epoch 10
# Epoch [10/100],Train Loss: 0.6110, Valid Loss: 0.62416213
# Starting epoch 11
# Epoch [11/100],Train Loss: 0.6091, Valid Loss: 0.57709094
# Model saved to ==> siameseNet.pt
# Starting epoch 12
# Epoch [12/100],Train Loss: 0.5980, Valid Loss: 0.61308047
# Starting epoch 13
# Epoch [13/100],Train Loss: 0.5780, Valid Loss: 0.56740244
# Model saved to ==> siameseNet.pt
# Starting epoch 14
# Epoch [14/100],Train Loss: 0.5588, Valid Loss: 0.57695325
# Starting epoch 15
# Epoch [15/100],Train Loss: 0.5520, Valid Loss: 0.58459603
# Starting epoch 16
# Epoch [16/100],Train Loss: 0.5533, Valid Loss: 0.60005564
# Starting epoch 17
# Epoch [17/100],Train Loss: 0.5513, Valid Loss: 0.53245890
# Model saved to ==> siameseNet.pt
# Starting epoch 18
# Epoch [18/100],Train Loss: 0.5323, Valid Loss: 0.55476242
# Starting epoch 19
# Epoch [19/100],Train Loss: 0.5430, Valid Loss: 0.49097052
# Model saved to ==> siameseNet.pt
# Starting epoch 20
# Epoch [20/100],Train Loss: 0.5089, Valid Loss: 0.48143549
# Model saved to ==> siameseNet.pt
# Starting epoch 21
# Epoch [21/100],Train Loss: 0.5206, Valid Loss: 0.47025997
# Model saved to ==> siameseNet.pt
# Starting epoch 22
# Epoch [22/100],Train Loss: 0.4960, Valid Loss: 0.50462411
# Starting epoch 23
# Epoch [23/100],Train Loss: 0.4734, Valid Loss: 0.50661377
# Starting epoch 24
# Epoch [24/100],Train Loss: 0.4539, Valid Loss: 0.45526800
# Model saved to ==> siameseNet.pt
# Starting epoch 25
# Epoch [25/100],Train Loss: 0.4558, Valid Loss: 0.46306957
# Starting epoch 26
# Epoch [26/100],Train Loss: 0.4381, Valid Loss: 0.47954751
# Starting epoch 27
# Epoch [27/100],Train Loss: 0.4223, Valid Loss: 0.46998150
# Starting epoch 28
# Epoch [28/100],Train Loss: 0.4157, Valid Loss: 0.39301922
# Model saved to ==> siameseNet.pt
# Starting epoch 29
# Epoch [29/100],Train Loss: 0.4290, Valid Loss: 0.42766941
# Starting epoch 30
# Epoch [30/100],Train Loss: 0.4284, Valid Loss: 0.38852202
# Model saved to ==> siameseNet.pt
# Starting epoch 31
# Epoch [31/100],Train Loss: 0.3957, Valid Loss: 0.42856978
# Starting epoch 32
# Epoch [32/100],Train Loss: 0.3793, Valid Loss: 0.34679302
# Model saved to ==> siameseNet.pt
# Starting epoch 33
# Epoch [33/100],Train Loss: 0.3881, Valid Loss: 0.44540134
# Starting epoch 34
# Epoch [34/100],Train Loss: 0.3709, Valid Loss: 0.39825907
# Starting epoch 35
# Epoch [35/100],Train Loss: 0.3720, Valid Loss: 0.36245867
# Starting epoch 36
# Epoch [36/100],Train Loss: 0.3469, Valid Loss: 0.38602101
# Starting epoch 37
# Epoch [37/100],Train Loss: 0.3632, Valid Loss: 0.43355566
# Starting epoch 38
# Epoch [38/100],Train Loss: 0.3603, Valid Loss: 0.34522621
# Model saved to ==> siameseNet.pt
# Starting epoch 39
# Epoch [39/100],Train Loss: 0.3804, Valid Loss: 0.33476682
# Model saved to ==> siameseNet.pt
# Starting epoch 40
# Epoch [40/100],Train Loss: 0.3253, Valid Loss: 0.33218021
# Model saved to ==> siameseNet.pt
# Starting epoch 41
# Epoch [41/100],Train Loss: 0.3072, Valid Loss: 0.33759758
# Starting epoch 42
# Epoch [42/100],Train Loss: 0.3345, Valid Loss: 0.37285797
# Starting epoch 43
# Epoch [43/100],Train Loss: 0.3128, Valid Loss: 0.28525289
# Model saved to ==> siameseNet.pt
# Starting epoch 44
# Epoch [44/100],Train Loss: 0.3407, Valid Loss: 0.28288644
# Model saved to ==> siameseNet.pt
# Starting epoch 45
# Epoch [45/100],Train Loss: 0.3093, Valid Loss: 0.23611176
# Model saved to ==> siameseNet.pt
# Starting epoch 46
# Epoch [46/100],Train Loss: 0.3120, Valid Loss: 0.27186452
# Starting epoch 47
# Epoch [47/100],Train Loss: 0.3176, Valid Loss: 0.24792517
# Starting epoch 48
# Epoch [48/100],Train Loss: 0.2893, Valid Loss: 0.30206962
# Starting epoch 49
# Epoch [49/100],Train Loss: 0.2906, Valid Loss: 0.30596474
# Starting epoch 50
# Epoch [50/100],Train Loss: 0.2849, Valid Loss: 0.26976500
# Starting epoch 51
# Epoch [51/100],Train Loss: 0.2736, Valid Loss: 0.27389849
# Starting epoch 52
# Epoch [52/100],Train Loss: 0.2651, Valid Loss: 0.28165105
# Starting epoch 53
# Epoch [53/100],Train Loss: 0.2894, Valid Loss: 0.24932806
# Starting epoch 54
# Epoch [54/100],Train Loss: 0.2685, Valid Loss: 0.26301336
# Starting epoch 55
# Epoch [55/100],Train Loss: 0.2839, Valid Loss: 0.26444732
# Starting epoch 56
# Epoch [56/100],Train Loss: 0.2874, Valid Loss: 0.29082847
# Starting epoch 57
# Epoch [57/100],Train Loss: 0.2872, Valid Loss: 0.28258236
# Starting epoch 58
# Epoch [58/100],Train Loss: 0.2504, Valid Loss: 0.25520276
# Starting epoch 59
# Epoch [59/100],Train Loss: 0.2445, Valid Loss: 0.22690853
# Model saved to ==> siameseNet.pt
# Starting epoch 60
# Epoch [60/100],Train Loss: 0.2472, Valid Loss: 0.31910664
# Starting epoch 61
# Epoch [61/100],Train Loss: 0.2511, Valid Loss: 0.26150041
# Starting epoch 62
# Epoch [62/100],Train Loss: 0.2578, Valid Loss: 0.21441493
# Model saved to ==> siameseNet.pt
# Starting epoch 63
# Epoch [63/100],Train Loss: 0.2513, Valid Loss: 0.24898377
# Starting epoch 64
# Epoch [64/100],Train Loss: 0.2436, Valid Loss: 0.22910392
# Starting epoch 65
# Epoch [65/100],Train Loss: 0.2527, Valid Loss: 0.22547340
# Starting epoch 66
# Epoch [66/100],Train Loss: 0.2387, Valid Loss: 0.21922955
# Starting epoch 67
# Epoch [67/100],Train Loss: 0.2275, Valid Loss: 0.19854088
# Model saved to ==> siameseNet.pt
# Starting epoch 68
# Epoch [68/100],Train Loss: 0.2545, Valid Loss: 0.20136858
# Starting epoch 69
# Epoch [69/100],Train Loss: 0.2620, Valid Loss: 0.19489099
# Model saved to ==> siameseNet.pt
# Starting epoch 70
# Epoch [70/100],Train Loss: 0.2507, Valid Loss: 0.28717778
# Starting epoch 71
# Epoch [71/100],Train Loss: 0.2323, Valid Loss: 0.20140082
# Starting epoch 72
# Epoch [72/100],Train Loss: 0.2189, Valid Loss: 0.18908487
# Model saved to ==> siameseNet.pt
# Starting epoch 73
# Epoch [73/100],Train Loss: 0.2049, Valid Loss: 0.21956159
# Starting epoch 74
# Epoch [74/100],Train Loss: 0.2475, Valid Loss: 0.22251489
# Starting epoch 75
# Epoch [75/100],Train Loss: 0.2184, Valid Loss: 0.22585031
# Starting epoch 76
# Epoch [76/100],Train Loss: 0.2213, Valid Loss: 0.23206000
# Starting epoch 77
# Epoch [77/100],Train Loss: 0.2159, Valid Loss: 0.23939577
# Starting epoch 78
# Epoch [78/100],Train Loss: 0.2139, Valid Loss: 0.16920183
# Model saved to ==> siameseNet.pt
# Starting epoch 79
# Epoch [79/100],Train Loss: 0.2148, Valid Loss: 0.21070630
# Starting epoch 80
# Epoch [80/100],Train Loss: 0.1888, Valid Loss: 0.20442346
# Starting epoch 81
# Epoch [81/100],Train Loss: 0.2154, Valid Loss: 0.18973312
# Starting epoch 82
# Epoch [82/100],Train Loss: 0.1907, Valid Loss: 0.18573595
# Starting epoch 83
# Epoch [83/100],Train Loss: 0.1952, Valid Loss: 0.19495381
# Starting epoch 84
# Epoch [84/100],Train Loss: 0.2119, Valid Loss: 0.21439544
# Starting epoch 85
# Epoch [85/100],Train Loss: 0.2185, Valid Loss: 0.21063883
# Starting epoch 86
# Epoch [86/100],Train Loss: 0.2159, Valid Loss: 0.18680563
# Starting epoch 87
# Epoch [87/100],Train Loss: 0.2110, Valid Loss: 0.20089573
# Starting epoch 88
# Epoch [88/100],Train Loss: 0.1854, Valid Loss: 0.22009959
# Starting epoch 89
# Epoch [89/100],Train Loss: 0.1895, Valid Loss: 0.24177138
# Starting epoch 90
# Epoch [90/100],Train Loss: 0.1703, Valid Loss: 0.21278555
# Starting epoch 91
# Epoch [91/100],Train Loss: 0.1729, Valid Loss: 0.17348503
# Starting epoch 92
# Epoch [92/100],Train Loss: 0.1781, Valid Loss: 0.16234606
# Model saved to ==> siameseNet.pt
# Starting epoch 93
# Epoch [93/100],Train Loss: 0.1783, Valid Loss: 0.16698302
# Starting epoch 94
# Epoch [94/100],Train Loss: 0.1875, Valid Loss: 0.16594382
# Starting epoch 95
# Epoch [95/100],Train Loss: 0.2083, Valid Loss: 0.14575321
# Model saved to ==> siameseNet.pt
# Starting epoch 96
# Epoch [96/100],Train Loss: 0.1927, Valid Loss: 0.18535148
# Starting epoch 97
# Epoch [97/100],Train Loss: 0.2031, Valid Loss: 0.15474594
# Starting epoch 98
# Epoch [98/100],Train Loss: 0.1796, Valid Loss: 0.18070954
# Starting epoch 99
# Epoch [99/100],Train Loss: 0.2034, Valid Loss: 0.16430091
# Starting epoch 100
# Epoch [100/100],Train Loss: 0.2093, Valid Loss: 0.15668544
# Finished Training

# %%
#plotting of training and validation loss
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label="Validation Loss")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# ### eval on test

# %%
from collections import Counter

# evaluation metrics
def eval(model, test_loader, at=3):
    with torch.no_grad():
        model.eval()
        print('Starting Iteration')
        count = 0
        prec = 0
        batch_rank = []
        for mainSong, songSet, label in test_loader:
            mainSong = mainSong.to(device)
            output_list = []
            for i, testSong in enumerate(songSet):
                testSong = testSong.to(device)
                output = model(mainSong, testSong)
                output_list.append(output)
            #computing rank within batch
            true_score = output_list[0]
            output_list.sort(reverse=True)
            rank = output_list.index(true_score) + 1
            batch_rank.append(rank)
            #computing precision
            if rank <= at:
              prec += 1
            #computing accuracy
            count += 1
            if count % 10 == 0:
                print("Current Count is: {}".format(count))
                print('Accuracy on n way: {}'.format(Counter(batch_rank)[1]/count))
        #metrics
        print(Counter(batch_rank).most_common())
        mean_rank = sum(batch_rank)/count
        mAP = 1/mean_rank
        final_acc = Counter(batch_rank)[1]/count
        prec_at = prec / count
    return mean_rank, mAP, prec_at, final_acc

# %%
# Evaluation on previously saved models
load_model = Net().to(device)
load_optimizer = optim.Adam(load_model.parameters(), lr=0.0006)

num_epochs = 10
eval_every = 1000
total_step = len(train_loader)*num_epochs
best_val_loss = load_checkpoint(load_model, load_optimizer, save_path)

print(best_val_loss)
eval(load_model, test_loader)
# Out:
# Model loaded from <== siameseNet.pt
# 0.1457532142608227
# Starting Iteration
# Current Count is: 10
# Accuracy on n way: 0.8
# Current Count is: 20
# Accuracy on n way: 0.8
# Current Count is: 30
# Accuracy on n way: 0.8333333333333334
# Current Count is: 40
# Accuracy on n way: 0.85
# Current Count is: 50
# Accuracy on n way: 0.84
# Current Count is: 60
# Accuracy on n way: 0.8333333333333334
# Current Count is: 70
# Accuracy on n way: 0.8285714285714286
# Current Count is: 80
# Accuracy on n way: 0.85
# Current Count is: 90
# Accuracy on n way: 0.8666666666666667
# Current Count is: 100
# Accuracy on n way: 0.85
# Current Count is: 110
# Accuracy on n way: 0.8545454545454545
# Current Count is: 120
# Accuracy on n way: 0.8416666666666667
# Current Count is: 130
# Accuracy on n way: 0.823076923076923
# Current Count is: 140
# Accuracy on n way: 0.8285714285714286
# Current Count is: 150
# Accuracy on n way: 0.82
# Current Count is: 160
# Accuracy on n way: 0.81875
# Current Count is: 170
# Accuracy on n way: 0.8235294117647058
# Current Count is: 180
# Accuracy on n way: 0.8277777777777777
# Current Count is: 190
# Accuracy on n way: 0.8315789473684211
# Current Count is: 200
# Accuracy on n way: 0.835
# [(1, 167), (2, 27), (4, 2), (8, 1), (5, 1), (10, 1), (3, 1)]
# (1.275, 0.7843137254901962, 0.975, 0.835)
